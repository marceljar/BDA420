# %%
import pandas as pd
import matplotlib.pyplot as plt
s = pd.Series([1, 3, 5, 6, 8])
plt.plot(s)

# %% [markdown]
# ## A Heading
# Some text
# A text with **bold** and *italic*
# > a quote

# %% [markdown]
# $e = mc^{2}$
