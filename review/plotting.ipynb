# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
toronto = pd.read_csv("../data/Toronto.csv", parse_dates=["Date"], index_col=False) # prevents errors due to malformed data
#toronto.set_index('Date', inplace=True)
montreal = pd.read_csv("../data/Montreal.csv", parse_dates=["Date"],index_col=False)

# %%
toronto_monthly = toronto.groupby([toronto['Date'].dt.year, toronto['Date'].dt.month]).mean()
montreal_monthly = montreal.groupby([montreal['Date'].dt.year, montreal['Date'].dt.month]).mean()

# %%
x = toronto_monthly[2013]["Max Temperature"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\Python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2013
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-349efc1078a5> in <module>
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(toronto_monthly.loc[2011]["Max Temperature"], label='Toronto')
ax.plot(montreal_monthly.loc[2011]["Max Temperature"], label='Montreal')
ax.set_title('Toronto and Montreal Temperatures')
ax.set_xlabel('Month')
ax.set_ylabel('Temperature')
ax.legend()
