# %%
import pandas as pd
import numpy as np

# %%
mu, sigma = 0, 0.1
data = np.random.normal(mu, sigma, 10000)

# %%
series = pd.Series(data)

# %%
series.describe()
#series.mean()
#series.var()
#series.std()
# Out:
# 0.0015282667752692157

# %%
print(series[0:9])
# Out:
# 0   -0.032644
# 1    0.124208
# 2    0.109871
# 3    0.264112
# 4   -0.175803
# 5   -0.077587
# 6   -0.127378
# 7   -0.088964
# 8    0.072480
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(series, bins = 20)
plt.show()
