# %% [markdown]
# # Workshop 02 - Apache Spark
# ### Your name goes here
# In this lab, we will answer a few questions with regards to Apache Spark. Note that, this time, you will use MarkDown to answer the questions, not Python code as usual.
#
# I understand that, when submitting this lab, I am abiding to Seneca's standards of academic honesty.

# %% [markdown]
# ### Question 1 (0.5  marks)
# Spark is described as “a unified computing engine and a set of libraries for parallel data processing on computer clusters.”
#
# Explain what is meant by computing engine and set of libraries, and describe how these two aspects work together in Spark.

# %% [markdown]
# ### Question 2 (0.5 marks)
# Why did the slowdown of CPU clock-speed improvements in the mid-2000s create the need for frameworks like Spark, and how does Spark address this problem?

# %% [markdown]
# ### Question 3 (0.5 marks)
# What is the role of Java Virtual Machines (JVM) within the Spark Framework?

# %% [markdown]
# ### Question 4 (0.5 marks)
# A Spark application follows a multi-step execution process involving a SparkSession, driver, cluster manager, and executors. Describe the lifecycle of a Spark application from the creation of a SparkSession to the return of final results to the user’s script.

# %% [markdown]
# ### Question 5 (0.5 marks)
# What is the difference between a transformation and an action in Spark, and why does Spark delay execution until an action is called?

# %% [markdown]
# ### Question 6 (0.5 marks)
# Spark provides three main data abstractions: RDDs, DataFrames, and Datasets. Compare these three abstractions in terms of immutability, level of abstraction, typing, and typical use cases.
