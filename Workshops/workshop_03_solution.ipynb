# %% [markdown]
# # Workshop 03 - Databricks
# ### Your name goes here
# In this lab, we will work on getting ourselves used to working with the databricks service. We will acheive this by performing a number of operations that require moving notebooks into databricks, fetching notebooks from databricks, and also importing data.
#
# I understand that, when submitting this lab, I am abiding to Seneca's standards of academic honesty.

# %% [markdown]
# #### Question 1 (1.0 mark)
# Import this notebook into your databricks account. Then, in the line below, simply use a Python print command to print your own name.

# %%
print("Marcel Jar")
# Out:
# Hello World

# %% [markdown]
# #### Question 2 (2.0 marks)
# Import data from the provided accounts.csv databaset, and create a database containing the data in this dataset. Make sure to set the options **header** and **inferSchema** to True.

# %%
path = "/FileStore/tables/accounts.csv"
df = spark.read.csv(path, header=True, inferSchema=True)

# %% [markdown]
# #### Question 2 (1.5 marks)
# Use the databricks **display** command to show the information in the dataframe created in the previous command as a scrollable and sortable table. Also, create a **Pie Chart** visualization that displays the number of active and inactive users.

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Question 3 (0.5 marks)
# Delete the *accounts.csv* dataset that you have added to your FileStore using **dbutils**.

# %%
new_path = "/FileStore/tables/accounts.csv"
dbutils.fs.rm(path, True)
# Out:
# Out[18]: False
